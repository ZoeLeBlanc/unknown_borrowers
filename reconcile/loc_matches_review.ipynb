# %%
# review & refine matches from Loc catalog
import pandas as pd

# %%
matches = pd.read_csv("shxco_loc_matches.csv")
total_matches = matches.shape[0]
print(f"Reviewing {total_matches:,} matches")
# Out:
# Reviewing 4,981 matches

# %%
# catalog record has trailing slash on the title, remove it
matches["title"] = matches.title.apply(lambda x: x.strip(" /"))

# %%
# identify matches where title and author match almost exactly; these are fine, no need to review those
import re
from slugify import slugify

# remove series names from titles; split on opening paren and return whatever is first
matches["sco_title_clean"] = matches.sco_title.apply(lambda x: x.split("(")[0])
# remove subtitles after semicolon or colon
matches["sco_title_nosub"] = matches.sco_title.apply(lambda x: re.split(r'[;:] ', x)[0])

# use slugify to ignore differences in case, accent, punctuation
matches["title_exact_match"] = matches.apply(lambda row: slugify(row.sco_title) == slugify(row.title), axis=1)
matches["title_nosub_exact_match"] = matches.apply(lambda row: slugify(row.sco_title_nosub) == slugify(row.title), axis=1)

# replace empty author NaNs with empty string to simplify comparison
matches.author = matches.author.fillna("")
matches.sco_author = matches.sco_author.fillna("")
# this check probably only works with single authors, but that's fine
matches["author_exact_match"] = matches.apply(lambda row: row.sco_author.lower() == row.author.lower(), axis=1)
title_exact = matches[matches.title_exact_match]
title_nosub_exact = matches[matches.title_nosub_exact_match]
author_exact = matches[matches.author_exact_match]
title_author_exact = matches[matches.title_exact_match & matches.author_exact_match]
title_author_exact_total = title_author_exact.shape[0]
title_author_exact_total = title_author_exact.shape[0]

title_or_titlenosub_author_exact = matches[(matches.title_exact_match | matches.title_nosub_exact_match) & matches.author_exact_match]
title_or_titlenosub_author_exact_total = title_or_titlenosub_author_exact.shape[0]

# reconcile search was based on author, so if author is set AT ALL and title matches with or without subtitle, we can include without review
title_or_titlenosub_with_author = matches[(matches.title_exact_match | matches.title_nosub_exact_match) & matches.author.notna()]
title_or_titlenosub_with_author_total = title_or_titlenosub_with_author.shape[0]

# another case: title matches and year matches
matches["sco_date"] = matches.date.astype("str")
title_or_titlenosub_with_year = matches[(matches.title_exact_match | matches.title_nosub_exact_match) & (matches.sco_date == matches.date)]
title_or_titlenosub_with_year_total = title_or_titlenosub_with_year.shape[0]


print(f"{title_exact.shape[0]:,} with exact title match")
print(f"{title_nosub_exact.shape[0]:,} with exact title match when ignoring subtitles")
print(f"{author_exact.shape[0]:,} with exact author match")
print(f"{title_author_exact_total:,} with exact title and author match")
print(f"{title_or_titlenosub_author_exact_total:,} with exact title and author match when ignoring subtitles")
print(f"{title_or_titlenosub_with_author_total:,} with exact title and author is present, matching title with or without subtitles")

print(f"{title_or_titlenosub_with_year_total:,} with title match (with or without subtitle) and year match")

print(f"{total_matches - title_or_titlenosub_with_author_total:,} matches to review based on author/title match")
print(f"{total_matches - title_or_titlenosub_with_year_total:,} matches to review based on title/year match")
# Out:
# 4,019 with exact title match
# 3,451 with exact title match when ignoring subtitles
# 3,898 with exact author match
# 3,270 with exact title and author match
# 3,309 with exact title and author match when ignoring subtitles
# 4,065 with exact title and author is present, matching title with or without subtitles
# 4,056 with title match (with or without subtitle) and year match
# 916 matches to review based on author/title match
# 925 matches to review based on title/year match

# %%
# identify matches that shoudl be reviewed
# - remove matches where title or subtitle matches and author is present
review_matches = matches[~((matches.title_exact_match | matches.title_nosub_exact_match) & matches.author.notna())].copy()
# - exclude any matches where title or subtitle matches and year matches
review_matches = review_matches[~(review_matches.title_exact_match | review_matches.title_nosub_exact_match) & (review_matches.sco_date == review_matches.date)]
review_matches
# Out:
#                                                  sco_id  \
# 2     https://shakespeareandco.princeton.edu/books/n...
# 4     https://shakespeareandco.princeton.edu/books/s...
# 5     https://shakespeareandco.princeton.edu/books/g...
# 6     https://shakespeareandco.princeton.edu/books/s...
# 12    https://shakespeareandco.princeton.edu/books/d...
# ...                                                 ...
# 4976  https://shakespeareandco.princeton.edu/books/m...
# 4977  https://shakespeareandco.princeton.edu/books/m...
# 4978  https://shakespeareandco.princeton.edu/books/j...
# 4979  https://shakespeareandco.princeton.edu/books/s...
# 4980  https://shakespeareandco.princeton.edu/books/t...
#
#                           sco_title  \
# 2                          Gorboduc
# 4          The Shepheard's Calendar
# 5     The Defence of Conny-Catching
# 6       A Midsummer's Night's Dream
# 12                     La géométrie
# ...                             ...
# 4976               Works of Marlowe
# 4977                  [Morand Book]
# 4978  [something by E. B. C. Jones]
# 4979          [Steinbeck's new one]
# 4980               [Tagore's Books]
#
#                                                   title            sco_author  \
# 2                               The tragedy of Gorboduc        Norton, Thomas
# 4     The faerie queen ; The shepheards calendar : t...       Spenser, Edmund
# 5     The blacke bookes messenger, 1592. Cuthbert Co...        Greene, Robert
# 6                             A midsummer night's dream  Shakespeare, William
# 12                      La géométrie de René Descartes.       Descartes, René
# ...                                                 ...                   ...
# 4976                  The works of Christopher Marlowe,  Marlowe, Christopher
# 4977                                       Paul Morand.          Morand, Paul
# 4978                                       [J.E. Jones]       Jones, E. B. C.
# 4979                                           La perla       Steinbeck, John
# 4980  Tagore literature : catalogue of books in the ...
#
#                                                  author    sco_date  \
# 2     norton, thomas;john davis batchelder collectio...        1736
# 4     spenser, edmund;george fabyan collection (libr...        1617
# 5                                        greene, robert        1966
# 6     lake, james h.;shakespeare, william;ford, john r.        2010
# 12                                      descartes, rené        1886
# ...                                                 ...         ...
# 4976                               marlowe, christopher        1970
# 4977                                       morand, paul        1966
# 4978                       jones, j. e.;hartman, george  1938-11-03
# 4979           steinbeck, john;bernal granados, gabriel        2019
# 4980                           sahitya akademi. library        1986
#
#             date                                    id  \
# 2           1736          http://lccn.loc.gov/96195076
# 4           1617          http://lccn.loc.gov/96133755
# 5           1966          http://lccn.loc.gov/66007098
# 6           2010        http://lccn.loc.gov/2015460287
# 12          1886        http://lccn.loc.gov/2001554104
# ...          ...                                   ...
# 4976        1970          http://lccn.loc.gov/73118945
# 4977        1966          http://lccn.loc.gov/66076909
# 4978  1938-11-03  http://www.loc.gov/item/wpalh000861/
# 4979        2019        http://lccn.loc.gov/2018034092
# 4980        1986          http://lccn.loc.gov/93907302
#
#                                                 subject  title_exact_match  \
# 2                                             tragedies              False
# 4                 knights and knighthood;poetry;virtues              False
# 5     social life and customs;england;london (englan...              False
# 6     a midsummer night's dream;athens (greece);man-...              False
# 12                      paris;france;geometry, analytic              False
# ...                                                 ...                ...
# 4976                                                NaN              False
# 4977                                                NaN              False
# 4978  field notes;local history;narratives;life hist...              False
# 4979                                           parables              False
# 4980                                                NaN              False
#
#       author_exact_match                sco_title_clean  \
# 2                  False                       Gorboduc
# 4                  False       The Shepheard's Calendar
# 5                   True  The Defence of Conny-Catching
# 6                  False    A Midsummer's Night's Dream
# 12                  True                   La géométrie
# ...                  ...                            ...
# 4976                True               Works of Marlowe
# 4977                True                  [Morand Book]
# 4978               False  [something by E. B. C. Jones]
# 4979               False          [Steinbeck's new one]
# 4980               False               [Tagore's Books]
#
#                     sco_title_nosub  title_nosub_exact_match
# 2                          Gorboduc                    False
# 4          The Shepheard's Calendar                    False
# 5     The Defence of Conny-Catching                    False
# 6       A Midsummer's Night's Dream                    False
# 12                     La géométrie                    False
# ...                             ...                      ...
# 4976               Works of Marlowe                    False
# 4977                  [Morand Book]                    False
# 4978  [something by E. B. C. Jones]                    False
# 4979          [Steinbeck's new one]                    False
# 4980               [Tagore's Books]                    False
#
# [904 rows x 14 columns]

# %%
# use levenshtein distance to calculate how similar the title and matched titles are
from Levenshtein import distance

# lower case, since we don't care about differences in case at this point
review_matches["title_dist"] = review_matches.apply(lambda row: distance(row.sco_title_clean.lower(), row.title.lower()), axis=1)

# %%
review_matches = review_matches.sort_values("title_dist", ascending=False)
review_matches[["sco_title", "sco_title_clean", "title", "title_dist", "sco_author", "author", "title_dist"]]
# Out:
#                                               sco_title  \
# 2074                                           May Fair
# 14                Vulgar Errors (Pseudodoxia Epidemica)
# 397                           The American Commonwealth
# 4021                                    The Flying Wasp
# 2196  Complete History of the Lives and Robberies of...
# ...                                                 ...
# 2335                 The Silver Spoon (A Modern Comedy)
# 2084          Original Letters from India (1779 – 1815)
# 4631                            The Trap (Pilgrimage 8)
# 4781                      Clear Horizon (Pilgrimage 11)
# 3202              Flowering Wilderness (End of Chapter)
#
#                                         sco_title_clean  \
# 2074                                           May Fair
# 14                                       Vulgar Errors
# 397                           The American Commonwealth
# 4021                                    The Flying Wasp
# 2196  Complete History of the Lives and Robberies of...
# ...                                                 ...
# 2335                                  The Silver Spoon
# 2084                       Original Letters from India
# 4631                                          The Trap
# 4781                                     Clear Horizon
# 3202                              Flowering Wilderness
#
#                                                   title  title_dist  \
# 2074  May Fair: being an entertainment purporting to...         326
# 14    The works of the learned Sr Thomas Brown, Kt.,...         313
# 397   The proposal to add six additional justices to...         270
# 4021  The flying wasp; a laughing look-over of what ...         269
# 2196  A complete history of the lives and robberies ...         248
# ...                                                 ...         ...
# 2335                                 The silver spoon /           1
# 2084                        Original letters from India           1
# 4631                                          The trap,           1
# 4781                                      Clear horizon           1
# 3202                              Flowering wilderness,           1
#
#                   sco_author  \
# 2074          Arlen, Michael
# 14            Browne, Thomas
# 397             Bryce, James
# 4021           O'Casey, Sean
# 2196        Smith, Alexander
# ...                      ...
# 2335        Galsworthy, John
# 2084              Fay, Eliza
# 4631  Richardson, Dorothy M.
# 4781  Richardson, Dorothy M.
# 3202        Galsworthy, John
#
#                                                  author  title_dist
# 2074                                     arlen, michael         326
# 14                                       browne, thomas         313
# 397   printed ephemera collection (library of congre...         270
# 4021                                      o'casey, sean         269
# 2196                                   smith, alexander         248
# ...                                                 ...         ...
# 2335                                   galsworthy, john           1
# 2084          fay, eliza;forster, e. m. (edward morgan)           1
# 4631            richardson, dorothy m. (dorothy miller)           1
# 4781            richardson, dorothy m. (dorothy miller)           1
# 3202                                   galsworthy, john           1
#
# [904 rows x 7 columns]

# %%
# load partial review done so far
partial_review = pd.read_csv("shxco_loc_matches_review_partial.csv")
# keep just the sco id, keep, and notes columns
partial_review = partial_review[["sco_id", "keep", "notes"]]
partial_review
# Out:
#                                                  sco_id  keep notes
# 0     https://shakespeareandco.princeton.edu/books/g...   1.0   NaN
# 1     https://shakespeareandco.princeton.edu/books/c...   1.0   NaN
# 2     https://shakespeareandco.princeton.edu/books/t...   1.0   NaN
# 3     https://shakespeareandco.princeton.edu/books/s...   1.0   NaN
# 4     https://shakespeareandco.princeton.edu/books/p...   1.0   NaN
# ...                                                 ...   ...   ...
# 1667  https://shakespeareandco.princeton.edu/books/g...   NaN   NaN
# 1668  https://shakespeareandco.princeton.edu/books/s...   NaN   NaN
# 1669  https://shakespeareandco.princeton.edu/books/o...   NaN   NaN
# 1670  https://shakespeareandco.princeton.edu/books/v...   NaN   NaN
# 1671  https://shakespeareandco.princeton.edu/books/t...   NaN   NaN
#
# [1672 rows x 3 columns]

# %%
review_merge = pd.merge(review_matches, partial_review, on="sco_id")
review_merge
# Out:
#                                                 sco_id  \
# 0    https://shakespeareandco.princeton.edu/books/a...
# 1    https://shakespeareandco.princeton.edu/books/b...
# 2    https://shakespeareandco.princeton.edu/books/b...
# 3    https://shakespeareandco.princeton.edu/books/o...
# 4    https://shakespeareandco.princeton.edu/books/s...
# ..                                                 ...
# 899  https://shakespeareandco.princeton.edu/books/g...
# 900  https://shakespeareandco.princeton.edu/books/f...
# 901  https://shakespeareandco.princeton.edu/books/r...
# 902  https://shakespeareandco.princeton.edu/books/r...
# 903  https://shakespeareandco.princeton.edu/books/g...
#
#                                              sco_title  \
# 0                                             May Fair
# 1                Vulgar Errors (Pseudodoxia Epidemica)
# 2                            The American Commonwealth
# 3                                      The Flying Wasp
# 4    Complete History of the Lives and Robberies of...
# ..                                                 ...
# 899                 The Silver Spoon (A Modern Comedy)
# 900          Original Letters from India (1779 – 1815)
# 901                            The Trap (Pilgrimage 8)
# 902                      Clear Horizon (Pilgrimage 11)
# 903              Flowering Wilderness (End of Chapter)
#
#                                                  title  \
# 0    May Fair: being an entertainment purporting to...
# 1    The works of the learned Sr Thomas Brown, Kt.,...
# 2    The proposal to add six additional justices to...
# 3    The flying wasp; a laughing look-over of what ...
# 4    A complete history of the lives and robberies ...
# ..                                                 ...
# 899                                 The silver spoon /
# 900                        Original letters from India
# 901                                          The trap,
# 902                                      Clear horizon
# 903                              Flowering wilderness,
#
#                  sco_author  \
# 0            Arlen, Michael
# 1            Browne, Thomas
# 2              Bryce, James
# 3             O'Casey, Sean
# 4          Smith, Alexander
# ..                      ...
# 899        Galsworthy, John
# 900              Fay, Eliza
# 901  Richardson, Dorothy M.
# 902  Richardson, Dorothy M.
# 903        Galsworthy, John
#
#                                                 author sco_date  date  \
# 0                                       arlen, michael     1925  1925
# 1                                       browne, thomas     1686  1686
# 2    printed ephemera collection (library of congre...     1937  1937
# 3                                        o'casey, sean     1971  1971
# 4                                     smith, alexander     1926  1926
# ..                                                 ...      ...   ...
# 899                                   galsworthy, john     2007  2007
# 900          fay, eliza;forster, e. m. (edward morgan)     2010  2010
# 901            richardson, dorothy m. (dorothy miller)     1925  1925
# 902            richardson, dorothy m. (dorothy miller)     1935  1935
# 903                                   galsworthy, john     1932  1932
#
#                                  id  \
# 0      http://lccn.loc.gov/25010419
# 1      http://lccn.loc.gov/20007180
# 2    http://lccn.loc.gov/2020782636
# 3      http://lccn.loc.gov/70173866
# 4      http://lccn.loc.gov/27013632
# ..                              ...
# 899  http://lccn.loc.gov/2009294787
# 900  http://lccn.loc.gov/2009031818
# 901    http://lccn.loc.gov/25019174
# 902    http://lccn.loc.gov/36009943
# 903    http://lccn.loc.gov/32028087
#
#                                                subject  title_exact_match  \
# 0    fiction;great britain;george v;london (england...              False
# 1    physicians;gardening;urn burial;english prose ...              False
# 2                                                  NaN              False
# 3    theater;english drama;20th century;history and...              False
# 4    great britain;thieves;crime and criminals;brig...              False
# ..                                                 ...                ...
# 899     forsyte family (fictitious characters);fiction              False
# 900  correspondence;social life and customs;england...              False
# 901                                                NaN              False
# 902     autobiographical fiction;fiction;england;women              False
# 903                                                NaN              False
#
#      author_exact_match                                    sco_title_clean  \
# 0                  True                                           May Fair
# 1                  True                                     Vulgar Errors
# 2                 False                          The American Commonwealth
# 3                  True                                    The Flying Wasp
# 4                  True  Complete History of the Lives and Robberies of...
# ..                  ...                                                ...
# 899                True                                  The Silver Spoon
# 900               False                       Original Letters from India
# 901               False                                          The Trap
# 902               False                                     Clear Horizon
# 903                True                              Flowering Wilderness
#
#                                        sco_title_nosub  \
# 0                                             May Fair
# 1                Vulgar Errors (Pseudodoxia Epidemica)
# 2                            The American Commonwealth
# 3                                      The Flying Wasp
# 4    Complete History of the Lives and Robberies of...
# ..                                                 ...
# 899                 The Silver Spoon (A Modern Comedy)
# 900          Original Letters from India (1779 – 1815)
# 901                            The Trap (Pilgrimage 8)
# 902                      Clear Horizon (Pilgrimage 11)
# 903              Flowering Wilderness (End of Chapter)
#
#      title_nosub_exact_match  title_dist  keep notes
# 0                      False         326   NaN   NaN
# 1                      False         313   NaN   NaN
# 2                      False         270   NaN   NaN
# 3                      False         269   1.0   NaN
# 4                      False         248   NaN   NaN
# ..                       ...         ...   ...   ...
# 899                    False           1   NaN   NaN
# 900                    False           1   NaN   NaN
# 901                    False           1   NaN   NaN
# 902                    False           1   NaN   NaN
# 903                    False           1   1.0   NaN
#
# [904 rows x 17 columns]

# %%
# how many left to review?
review_merge[~review_merge.keep.notna()]
# Out:
#                                                 sco_id  \
# 0    https://shakespeareandco.princeton.edu/books/a...
# 1    https://shakespeareandco.princeton.edu/books/b...
# 2    https://shakespeareandco.princeton.edu/books/b...
# 4    https://shakespeareandco.princeton.edu/books/s...
# 7    https://shakespeareandco.princeton.edu/books/g...
# ..                                                 ...
# 898  https://shakespeareandco.princeton.edu/books/g...
# 899  https://shakespeareandco.princeton.edu/books/g...
# 900  https://shakespeareandco.princeton.edu/books/f...
# 901  https://shakespeareandco.princeton.edu/books/r...
# 902  https://shakespeareandco.princeton.edu/books/r...
#
#                                              sco_title  \
# 0                                             May Fair
# 1                Vulgar Errors (Pseudodoxia Epidemica)
# 2                            The American Commonwealth
# 4    Complete History of the Lives and Robberies of...
# 7                                The Gold of [unclear]
# ..                                                 ...
# 898             The Man of Property (The Forsyte Saga)
# 899                 The Silver Spoon (A Modern Comedy)
# 900          Original Letters from India (1779 – 1815)
# 901                            The Trap (Pilgrimage 8)
# 902                      Clear Horizon (Pilgrimage 11)
#
#                                                  title  \
# 0    May Fair: being an entertainment purporting to...
# 1    The works of the learned Sr Thomas Brown, Kt.,...
# 2    The proposal to add six additional justices to...
# 4    A complete history of the lives and robberies ...
# 7    Original Unpublished Collection of Maps Relati...
# ..                                                 ...
# 898                               The man of property.
# 899                                 The silver spoon /
# 900                        Original letters from India
# 901                                          The trap,
# 902                                      Clear horizon
#
#                  sco_author  \
# 0            Arlen, Michael
# 1            Browne, Thomas
# 2              Bryce, James
# 4          Smith, Alexander
# 7
# ..                      ...
# 898        Galsworthy, John
# 899        Galsworthy, John
# 900              Fay, Eliza
# 901  Richardson, Dorothy M.
# 902  Richardson, Dorothy M.
#
#                                                 author sco_date  date  \
# 0                                       arlen, michael     1925  1925
# 1                                       browne, thomas     1686  1686
# 2    printed ephemera collection (library of congre...     1937  1937
# 4                                     smith, alexander     1926  1926
# 7          martínez compañon y bujanda, baltazar jaime     1782  1782
# ..                                                 ...      ...   ...
# 898                                   galsworthy, john     1921  1921
# 899                                   galsworthy, john     2007  2007
# 900          fay, eliza;forster, e. m. (edward morgan)     2010  2010
# 901            richardson, dorothy m. (dorothy miller)     1925  1925
# 902            richardson, dorothy m. (dorothy miller)     1935  1935
#
#                                       id  \
# 0           http://lccn.loc.gov/25010419
# 1           http://lccn.loc.gov/20007180
# 2         http://lccn.loc.gov/2020782636
# 4           http://lccn.loc.gov/27013632
# 7    http://www.loc.gov/item/2021667799/
# ..                                   ...
# 898         http://lccn.loc.gov/25022191
# 899       http://lccn.loc.gov/2009294787
# 900       http://lccn.loc.gov/2009031818
# 901         http://lccn.loc.gov/25019174
# 902         http://lccn.loc.gov/36009943
#
#                                                subject  title_exact_match  \
# 0    fiction;great britain;george v;london (england...              False
# 1    physicians;gardening;urn burial;english prose ...              False
# 2                                                  NaN              False
# 4    great britain;thieves;crime and criminals;brig...              False
# 7    missionaries;missions;codex;cities and towns;1...              False
# ..                                                 ...                ...
# 898     forsyte family (fictitious characters);fiction              False
# 899     forsyte family (fictitious characters);fiction              False
# 900  correspondence;social life and customs;england...              False
# 901                                                NaN              False
# 902     autobiographical fiction;fiction;england;women              False
#
#      author_exact_match                                    sco_title_clean  \
# 0                  True                                           May Fair
# 1                  True                                     Vulgar Errors
# 2                 False                          The American Commonwealth
# 4                  True  Complete History of the Lives and Robberies of...
# 7                 False                              The Gold of [unclear]
# ..                  ...                                                ...
# 898                True                               The Man of Property
# 899                True                                  The Silver Spoon
# 900               False                       Original Letters from India
# 901               False                                          The Trap
# 902               False                                     Clear Horizon
#
#                                        sco_title_nosub  \
# 0                                             May Fair
# 1                Vulgar Errors (Pseudodoxia Epidemica)
# 2                            The American Commonwealth
# 4    Complete History of the Lives and Robberies of...
# 7                                The Gold of [unclear]
# ..                                                 ...
# 898             The Man of Property (The Forsyte Saga)
# 899                 The Silver Spoon (A Modern Comedy)
# 900          Original Letters from India (1779 – 1815)
# 901                            The Trap (Pilgrimage 8)
# 902                      Clear Horizon (Pilgrimage 11)
#
#      title_nosub_exact_match  title_dist  keep notes
# 0                      False         326   NaN   NaN
# 1                      False         313   NaN   NaN
# 2                      False         270   NaN   NaN
# 4                      False         248   NaN   NaN
# 7                      False         225   NaN   NaN
# ..                       ...         ...   ...   ...
# 898                    False           1   NaN   NaN
# 899                    False           1   NaN   NaN
# 900                    False           1   NaN   NaN
# 901                    False           1   NaN   NaN
# 902                    False           1   NaN   NaN
#
# [623 rows x 17 columns]

# %%
# save to csv for manual review; specify encoding so we get byte order mark for excel
review_matches.to_csv("shxco_loc_matches_review.csv", index=False, encoding='utf-8-sig')

# %%
# save to csv for manual review; specify encoding so we get byte order mark for excel
review_merge.to_csv("shxco_loc_matches_review.csv", index=False, encoding='utf-8-sig')

# %%
# manually reviewed the ones that were questionable and indicated keep yes or no
# use the manual review to filter the full set of matches

reviewed = pd.read_csv("shxco_loc_matches_reviewed.csv")
matches = pd.read_csv("shxco_loc_matches.csv")

final_matches = matches[~matches.sco_id.isin(reviewed[reviewed.keep == 0].sco_id)]
final_matches
# Out:
#                                                  sco_id  \
# 0     https://shakespeareandco.princeton.edu/books/m...
# 1     https://shakespeareandco.princeton.edu/books/m...
# 2     https://shakespeareandco.princeton.edu/books/n...
# 3     https://shakespeareandco.princeton.edu/books/l...
# 4     https://shakespeareandco.princeton.edu/books/s...
# ...                                                 ...
# 4974  https://shakespeareandco.princeton.edu/books/j...
# 4975  https://shakespeareandco.princeton.edu/books/l...
# 4976  https://shakespeareandco.princeton.edu/books/m...
# 4977  https://shakespeareandco.princeton.edu/books/m...
# 4980  https://shakespeareandco.princeton.edu/books/t...
#
#                         sco_title  \
# 0               Le Morte d'Arthur
# 1                          Utopia
# 2                        Gorboduc
# 3     Euphues: The Anatomy of Wit
# 4        The Shepheard's Calendar
# ...                           ...
# 4974             Work in Progress
# 4975        Works of Charles Lamb
# 4976             Works of Marlowe
# 4977                [Morand Book]
# 4980             [Tagore's Books]
#
#                                                   title            sco_author  \
# 0                                   Le morte d'Arthur /        Malory, Thomas
# 1                                              Utopia /          More, Thomas
# 2                               The tragedy of Gorboduc        Norton, Thomas
# 3                          Euphues. The anatomy of wit.            Lyly, John
# 4     The faerie queen ; The shepheards calendar : t...       Spenser, Edmund
# ...                                                 ...                   ...
# 4974                                  Work in progress.          Joyce, James
# 4975                         The works of Charles Lamb.         Lamb, Charles
# 4976                  The works of Christopher Marlowe,  Marlowe, Christopher
# 4977                                       Paul Morand.          Morand, Paul
# 4980  Tagore literature : catalogue of books in the ...                   NaN
#
#                                                  author  sco_date  date  \
# 0                                        malory, thomas    1485.0  1985
# 1                                          more, thomas    1516.0  1999
# 2     norton, thomas;john davis batchelder collectio...    1561.0  1736
# 3                                            lyly, john    1578.0  1868
# 4     spenser, edmund;george fabyan collection (libr...    1579.0  1617
# ...                                                 ...       ...   ...
# 4974                                       joyce, james       NaN  1927
# 4975                                      lamb, charles       NaN  1840
# 4976                               marlowe, christopher       NaN  1970
# 4977                                       morand, paul       NaN  1966
# 4980                           sahitya akademi. library       NaN  1986
#
#                                    id  \
# 0        http://lccn.loc.gov/85240163
# 1        http://lccn.loc.gov/00268291
# 2        http://lccn.loc.gov/96195076
# 3        http://lccn.loc.gov/12008363
# 4        http://lccn.loc.gov/96133755
# ...                               ...
# 4974     http://lccn.loc.gov/28001908
# 4975  http://lccn.loc.gov/unk83030218
# 4976     http://lccn.loc.gov/73118945
# 4977     http://lccn.loc.gov/66076909
# 4980     http://lccn.loc.gov/93907302
#
#                                                 subject
# 0                                    arthurian romances
# 1                           utopias;early works to 1800
# 2                                             tragedies
# 3     triangles (interpersonal relations);naples (it...
# 4                 knights and knighthood;poetry;virtues
# ...                                                 ...
# 4974                                                NaN
# 4975                                                NaN
# 4976                                                NaN
# 4977                                                NaN
# 4980                                                NaN
#
# [4846 rows x 9 columns]

# %%
final_matches.to_csv("shxco_loc_matches_final.csv", index=False)
